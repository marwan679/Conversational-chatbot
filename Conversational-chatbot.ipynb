# %% [markdown]
# # Installations

# %%
# Install correct packages
# %pip install langchain-core langchain-community

# %% [markdown]
# # Imports

# %%
from langchain.messages import HumanMessage, SystemMessage , AIMessage
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = ...

# %% [markdown]
# # models to use:
# #### Modelrepo_idQwen 2.5 72B ✅
# #### Qwen/Qwen2.5-72B-InstructDeepSeek R1 ✅
# #### deepseek-ai/DeepSeek-R1-0528Llama 3.3 70B ✅
# #### meta-llama/Llama-3.3-70B-InstructMistral Small ✅
# #### mistralai/Mistral-Small-3.1-24B-Instruct-2503Phi-4 ✅
# #### microsoft/phi-4/✅

# %% [markdown]
# # Initializing LLM

# %%
# 1. Connect to HuggingFace model
llm = HuggingFaceEndpoint(
    repo_id="Qwen/Qwen2.5-72B-Instruct", 
    huggingfacehub_api_token="hf_boGBPIkpLUXPsHNQNIQhqRkldeMoxKBtVT",
    task="conversational",
    max_new_tokens=512,
)
chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# # Inference

# %%
result = chat_model.invoke([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the capital of France?"),
])
result.content
# Out:
# 'Paris'

# %%
result = chat_model.invoke([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is langchain?"),
])
print(result.content)
# Out:
# LangChain is a framework and a library for building applications that utilize large language models (LLMs) and other AI models. It provides a set of tools, abstractions, and best practices to help developers integrate and leverage these models in their applications more effectively. Here are some key aspects of LangChain:
#
# ### 1. **Model Integration**
#    - **LLM Support**: LangChain supports a variety of large language models, including those from OpenAI, Anthropic, and others.
#    - **API Wrappers**: It provides easy-to-use wrappers for interacting with these models, making it simpler to send and receive data.
#
# ### 2. **Data Handling**
#    - **Document Loaders**: Tools to load and preprocess documents, making it easier to work with unstructured data.
#    - **Text Splitters**: Methods to split large documents into smaller chunks, which is useful for feeding data into LLMs.
#
# ### 3. **Memory Management**
# ...
